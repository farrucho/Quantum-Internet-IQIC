# %%
from sequence.gui.run_gui import RunGui

if __name__ == '__main__':
    gui = RunGui('Test Project')
    gui.load_graph()
    gui.gui.run_server(debug=False, host="127.0.0.1", port="8050")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sequence.gui.run_gui import RunGui
#       3 if __name__ == '__main__':
#       4     gui = RunGui('Test Project')
#
# File ~/anaconda3/envs/qiskit/lib/python3.10/site-packages/sequence/gui/run_gui.py:7
#       4 import pandas as pd
#       5 import numpy as np
# ----> 7 from .app import QuantumGUI
#       8 from .graph_comp import GraphNode
#       9 from ..topology.topology import Topology
#
# File ~/anaconda3/envs/qiskit/lib/python3.10/site-packages/sequence/gui/app.py:23
#      20 from dash.dependencies import Input, Output, State
#      22 from .simulator_bindings import GUI_Sim
# ---> 23 from .menus import *
#      24 from .graph_comp import GraphNode
#      25 from .layout import get_app_layout
#
# File ~/anaconda3/envs/qiskit/lib/python3.10/site-packages/sequence/gui/menus.py:858
#     762 results_menu = dbc.Form(
#     763     [
#     764         html.H5("Results"),
#    (...)
#     775     ]
#     776 )
#     778 simulation_menu = html.Div(
#     779     [
#     780         html.H3('Run (WIP)'),
#    (...)
#     850     style=MENU_STYLE
#     851 )
#     853 navbar = dbc.Navbar(
#     854     children=[
#     855         html.A(
#     856             dbc.Row(
#     857                 [
# --> 858                     dbc.Col(getLogo('sequence.jpg', '80px')),
#     859                     dbc.Col(dbc.NavbarBrand(
#     860                         "SeQUeNCe",
#     861                         className="ml-2",
#     862                         style={
#     863                             'font-size': '50px'
#     864                         }
#     865                     )),
#     866                 ],
#     867                 align="center",
#     868                 className="g-0"
#     869             ),
#     870             href="https://github.com/sequence-toolbox",
#     871             style={
#     872                 'position': 'relative',
#     873                 'top': '0px',
#     874                 'left': '10px'
#     875             }
#     876         ),
#     877         dbc.Row(
#     878             [
#     879                 dbc.NavLink(
#     880                     'New Network',
#     881                     id='new_network',
#     882                     style={
#     883                         'color': 'white'
#     884                     },
#     885                 ),
#     886                 # dbc.NavLink(
#     887                 #     'Save',
#     888                 #     id='save_network',
#     889                 #     style={
#     890                 #         'color': 'white'
#     891                 #     }
#     892                 # ),
#     893                 # dbc.NavLink(
#     894                 #     'Load',
#     895                 #     id='load_network',
#     896                 #     style={
#     897                 #         'color': 'white'
#     898                 #     }
#     899                 # ),
#     900                 dbc.DropdownMenu(
#     901                     [
#     902                         dbc.DropdownMenuItem('All', id='export_all'),
#     903                         dbc.DropdownMenuItem('Topology', id='export_topo'),
#     904                         dbc.DropdownMenuItem('Templates', id='export_templ'),
#     905                         dbc.DropdownMenuItem('Simulation', id='export_sim')
#     906                     ],
#     907                     label="Export",
#     908                     group=True,
#     909                     size='sm',
#     910                     nav=True,
#     911                     in_navbar=True,
#     912                     toggle_style={
#     913                         'color': 'white'
#     914                     }
#     915                 ),
#     916                 dbc.DropdownMenu(
#     917                     children=[
#     918                         dbc.DropdownMenuItem(
#     919                             "Help",
#     920                             href='https://sequence-toolbox.github.io/',
#     921                         ),
#     922                         dbc.DropdownMenuItem(
#     923                             'Report Issue',
#     924                             href='https://github.com/sequence-toolbox/SeQUeNCe/issues',  # nopep8
#     925                         ),
#     926                     ],
#     927                     label="More",
#     928                     group=True,
#     929                     size='sm',
#     930                     nav=True,
#     931                     in_navbar=True,
#     932                     # right=True,
#     933                     toggle_style={
#     934                         'color': 'white'
#     935                     }
#     936                 ),
#     937             ],
#     938             className="ml-auto flex-nowrap mt-3 mt-md-0 g-0",
#     939             align="center",
#     940         )
#     941     ],
#     942     color="dark",
#     943     dark=True,
#     944 )
#     947 def get_network(elements_in):
#     948     return cyto.Cytoscape(
#     949         id='graph',
#     950         layout={
#    (...)
#     981         ]
#     982     )
#
# File ~/anaconda3/envs/qiskit/lib/python3.10/site-packages/sequence/gui/menus.py:139, in getLogo(filename, width, link)
#     137 def getLogo(filename, width, link=None):
#     138     image_filename = os.path.join(DIRECTORY, 'assets', filename)
# --> 139     encoded_image = base64.b64encode(open(image_filename, 'rb').read())
#     140     image = html.Img(
#     141         src='data:image/png;base64,{}'.format(encoded_image.decode()),
#     142         width=width,
#     143         style={'border-radius': '20%'})
#     144     if link is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/duartegoncalves/anaconda3/envs/qiskit/lib/python3.10/site-packages/sequence/gui/assets/sequence.jpg'
